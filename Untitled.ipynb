# %%
string=input("enter the string")
def minion_game(string):
    s=len(string)
    vowel=0
    consonent=0
    for i in range(s):
        if string[i] in "AEIOU":
            vowel+=(s-i)
        else:
            consonent+=(s-i)
    if vowel>consonent:
        print("Kevin",str(vowel))
    elif vowel<consonent:
        print("stuar wins")
    else:
        print("draw")
minion_game(string)
# Out:
# enter the string EDUCATION
# Kevin 26

# %%
with open("mmm.txt","r")as file:
    content=file.read()
    print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open("mmm.txt","r")as file:
#       2     content=file.read()
#       3     print(content)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mmm.txt'

# %%
a=10
print(a)
print(a**2)
print(a*2)
print(a/3)
print(a//3)
print(a%3)
a+=3  #a+=3 / a=a+3
print(a)
# Out:
# 10
# 100
# 20
# 3.3333333333333335
# 3
# 1
# 13

# %%
x=5
x<10 and x>10
# Out:
# False

# %%
def removenth(s,n):
    if n >= len(s):
        return s
    return s[:n] + s[n+1:]

s=input("enter string")    
n=int(input("enter index"))
print(removenth(s,n))
# Out:
# enter string Mango
# enter index 1
# Mngo

# %%
a=list(input("enter the string").split(","))
a.sort()
print(a)
# Out:
# enter the string without, hello, bag, world
# [' bag', ' hello', ' world', 'without']

# %%
words = ["Python", "is", "easy"]
result = " ".join(words)
print(result)
# Out:
# Python is easy

# %%
def square(r):
    r**=2
    return(r)
r=int(input("enter a value"))
print(square(r))
# Out:
# enter a value 3
# 9

# %%
def Max(a):
    return max(a)
a=list(map(int,input("enter the value").split(",")))
print(Max(a))
# Out:
# enter the value 17,99,66
# 99

# %%
def fact(n):
    f=1
    if n==0: 
        print("1")
    else:
        for a in range(1,n+1):
            f*=a
    n=f
    return(n)
n=int(input("enter he value"))
print(fact(n))
# Out:
# enter he value 0
# 1
# 1

# %%
def Remove(a,t):
    if t in a:
        a.remove(t)
    else:
        print("the element")
    return a
a=list(input("enter"))
t=input("element to delete")
print(Remove(a,t))
# Out:
# enter apple
# element to delete p
# ['a', 'p', 'l', 'e']

# %%
keys = ('a', 'b', 'c')
values = (1, 2)

dict(zip(keys, values))
# Out:
# {'a': 1, 'b': 2}

# %%
a="abcdefghijklmnopqrst"
b=a[-1:]+a[1:len(a)-1]+a[0]
print(b)
# Out:
# tbcdefghijklmnopqrsa

# %%
import csv

filename = "data.csv"
column_name = "Marks"
threshold = 60

with open(filename, "r") as file:
    reader = csv.DictReader(file)
    
    for row in reader:
        if int(row[column_name]) > threshold:
            print(row)

# %%
a="hello"
b={}
for i in set(a):
    b[i] = a.count(i)

print(b)
# Out:
# {'o': 1, 'l': 2, 'h': 1, 'e': 1}

# %%
with open("input.txt", "r") as f:
    lines = f.readlines()

content = "".join(lines)      # convert list to string
reversed_content = content[::-1]
output = ",".join(reversed_content)

print(output)

# %%
digit_words = {
    '0': 'zero',
    '1': 'one',
    '2': 'two',
    '3': 'three',
    '4': 'four',
    '5': 'five',
    '6': 'six',
    '7': 'seven',
    '8': 'eight',
    '9': 'nine'
}

with open("input.txt", "r") as f:
    content = f.read()

result = ""

for ch in content:
    if ch.isdigit():
        result += digit_words[ch] + " "
    else:
        result += ch

print(result)

# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df)

# %%
import pandas as pd

data = pd.Series([10, 20, 15, 30, 25],
                 index=["Jan", "Feb", "Mar", "Apr", "May"])
import matplotlib.pyplot as plt

plt.pie(data)
plt.xlabel("Months")
plt.ylabel("Values")
plt.title("Line Chart from Pandas Series")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read CSV file
df = pd.read_csv("cities.csv")

# Step 2: Remove last column and store remaining columns in an array
data_array = df.iloc[:, :-1].values

# Step 3: Store last column in another array
last_column_array = df.iloc[:, -1].values

# Step 4: Plot first two columns
plt.plot(df.iloc[:, 0], df.iloc[:, 1])
plt.xlabel(df.columns[0])
plt.ylabel(df.columns[1])
plt.title("Plot of First Two Columns")
plt.show()

# %%
X = [5,8,4,6,7]
n=100
'''l= len(X)
c= 0
for s in X:
    c+=s

cMean= c/l

UCl = cMean + 3*(cMean**(0.5))
LCl = cMean - 3*(cMean**(0.5)) 
CL = cMean

print(UCl)
print(LCl)
print(CL)'''
p=sum(X)/(len(X)*n)
print("sum(d):", sum(X))
print("len(d):", len(X))
print("n:", n)
print("p:", p)
print("CL:", n*p)
# Out:
# sum(d): 30
# len(d): 5
# n: 100
# p: 0.06
# CL: 6.0
